# %%
import chromadb
import pandas as pd
client = chromadb.Client()

# %%
collection = client.get_or_create_collection(name="my_collection")

# %%
collection.add(
    ids=["id1", "id2"],
    documents=[
        "This is a document about pineapple",
        "This is a document about oranges"
    ]
)
#results = collection.peek(2)
#display(results)
